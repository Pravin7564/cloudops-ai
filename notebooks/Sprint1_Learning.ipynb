# %% [markdown]
# # CloudOps AI
# THIS IS MAIN PROJECT

# %% [markdown]
# ## Sprint 01 Learning Notebook
#
# **Author:** Pravin
#
# **Version:** 1.0
#
# **Sprint:** Sprint 01
#
# **Status:** Completed

# %% [markdown]
# [link text](https://)# Import Libraries

# %% [markdown]
# Sprint Goal

# %% [markdown]
# ### Sprint Goal
#
# Learn the basic concepts required to build the first AI-powered CloudOps application.
#
# Topics:
#
# - Python Basics
# - JSON
# - Prompt Engineering
# - Gemini API
# - Project Structure

# %% [markdown]
# ### Python Basics

# %%
### Variables
name = "Pravin"

print(name)
# Out:
# Pravin

# %%
###Lists
commands = [
    "kubectl get pods",
    "kubectl logs",
    "kubectl describe pod"
]

for command in commands:
    print(command)
# Out:
# kubectl get pods
# kubectl logs
# kubectl describe pod

# %%
###Functions
def analyze_kubernetes_log(log):
    print("Analyzing...")
    print(log)

# %% [markdown]
# ### JSON

# %%
##JSON Basics
analysis = {
    "RootCause": "CrashLoopBackOff",
    "Severity": "High"
}

print(analysis)
# Out:
# {'RootCause': 'CrashLoopBackOff', 'Severity': 'High'}

# %% [markdown]
# ### Prompt Engineering

# %%
prompt = """
You are a Senior Kubernetes Site Reliability Engineer.

Explain the following Kubernetes issue:

CrashLoopBackOff
"""

print(prompt)
# Out:
# You are a Senior Kubernetes Site Reliability Engineer.
#
# Explain the following Kubernetes issue:
#
# CrashLoopBackOff

# %% [markdown]
# ### Gemini API

# %%
### Import Required Libraries
from google import genai
from google.colab import userdata

# %%
### Create Gemini Client
api_key = userdata.get("GeminiAPIKEY")

client = genai.Client(api_key=api_key)

# %%
### Verify Connection
response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Reply with CloudOps AI Connected"
)

print(response.text)
# Out:
# CloudOps AI Connected

# %% [markdown]
# ### Experiments

# %%
question = "Explain Kubernetes Pods in simple language."

response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents=question
)

print(response.text)
# Out:
# Imagine you are running a restaurant.
#
# In the world of software, your food recipes are **Containers** (like Docker), but **Kubernetes** is the kitchen manager.
#
# And in this kitchen, a **Pod** is the **serving plate**.
#
# Here is the simplest way to understand Kubernetes Pods.
#
# ---
#
# ### 1. What is a Pod?
# A Pod is the **smallest building block** in Kubernetes.
#
# Kubernetes doesn't run containers directly on your servers. Instead, it wraps one or more containers inside a protective shell called a **Pod**.
#
# Most of the time, **one Pod contains only one container** (for example, your web application).
#
# ### 2. The "Space Capsule" Analogy
# To understand how a Pod works, imagine a **Space Capsule**:
#
# * **The Capsule is the Pod.**
# * **The Astronauts inside are the Containers.**
#
# Inside this capsule:
# * **They share resources:** The astronauts share the same air, water, and power. In a Pod, the containers share the same IP address, network, and storage.
# ...

# %% [markdown]
# ### Learnings
#
# - Learned Python variables.
# - Learned Python lists.
# - Learned functions.
# - Learned JSON.
# - Connected to Gemini.
# - Understood prompt engineering.

# %% [markdown]
# ### Next Steps
#
# - Move reusable code into the backend folder.
#
# - Build the Kubernetes Log Analyzer.
#
# - Separate learning code from production code.
